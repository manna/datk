# %%
# %run imports.py

# %%
x = Random_Line_Network(10)

# %%
x.draw()

# %%
x.state()
# Out:
# [('P5', {'n': 10}),
#  ('P7', {'n': 10}),
#  ('P2', {'n': 10}),
#  ('P4', {'n': 10}),
#  ('P8', {'n': 10}),
#  ('P3', {'n': 10}),
#  ('P1', {'n': 10}),
#  ('P6', {'n': 10}),
#  ('P0', {'n': 10}),
#  ('P9', {'n': 10})]

# %%
SynchFloodMax(x)
# Out:
# ------------------------
# Running SynchFloodMax on
# [P5 -> {P7}, P7 -> {P5, P2}, P2 -> {P7, P4, P8}, P4 -> {P2, P8}, P8 -> {P2, P4, P3}, P3 -> {P8, P1}, P1 -> {P3, P6, P0}, P6 -> {P1, P0}, P0 -> {P1, P6, P9}, P9 -> {P0}]
# Round 1
# Round 2
# Round 3
# Round 4
# Round 5
# Round 6
# Round 7
# Round 8
# Round 9
# Round 10
# P5.status is non-leader
# P7.status is non-leader
# P2.status is non-leader
# P4.status is non-leader
# P8.status is non-leader
# P3.status is non-leader
# P1.status is non-leader
# P6.status is non-leader
# P0.status is non-leader
# P9.status is leader
# SynchFloodMax Terminated
# Message Complexity: 198
# Time Complexity: 10
# -------------------
# <datk.core.algs.SynchFloodMax instance at 0x10d33f1b8>

# %%
x.draw()

# %%
x.state()
# Out:
# [('P6', {'n': 10, 'status': 'non-leader'}),
#  ('P0', {'n': 10, 'status': 'non-leader'}),
#  ('P4', {'n': 10, 'status': 'non-leader'}),
#  ('P8', {'n': 10, 'status': 'non-leader'}),
#  ('P7', {'n': 10, 'status': 'non-leader'}),
#  ('P1', {'n': 10, 'status': 'non-leader'}),
#  ('P3', {'n': 10, 'status': 'non-leader'}),
#  ('P2', {'n': 10, 'status': 'non-leader'}),
#  ('P9', {'n': 10, 'status': 'leader'}),
#  ('P5', {'n': 10, 'status': 'non-leader'})]

# %%
assertLeaderElection(x)

# %%
x = Random_Line_Network(13, sparsity=0.1)

# %%
x.draw()

# %%
SynchLubyMIS(x)
# Out:
# -----------------------
# Running SynchLubyMIS on
# [P11 -> {P4, P6, P9, P12, P10, P5, P2}, P4 -> {P11, P6, P9, P10, P5, P3, P1}, P6 -> {P11, P4, P9, P12, P10, P5, P3}, P9 -> {P11, P4, P6, P12, P10, P5, P1, P0, P2}, P12 -> {P11, P6, P9, P10, P5, P3, P1, P0}, P10 -> {P11, P4, P6, P9, P12, P5, P3, P8, P1, P7}, P5 -> {P11, P4, P6, P9, P12, P10, P3, P8, P1, P0}, P3 -> {P4, P6, P12, P10, P5, P8, P1, P0, P2, P7}, P8 -> {P10, P5, P3, P1, P7}, P1 -> {P4, P9, P12, P10, P5, P3, P8, P0, P2}, P0 -> {P9, P12, P5, P3, P1, P2, P7}, P2 -> {P11, P9, P3, P1, P0, P7}, P7 -> {P10, P3, P8, P0, P2}]
# Round 1
# P8.MIS is True
# P0.MIS is True
# Round 2
# P9.MIS is False
# P12.MIS is False
# P10.MIS is False
# P5.MIS is False
# P3.MIS is False
# P1.MIS is False
# P2.MIS is False
# P7.MIS is False
# Round 3
# Round 4
# P11.MIS is True
# Round 5
# P4.MIS is False
# P6.MIS is False
# Round 6
# SynchLubyMIS Terminated
# Message Complexity: 191
# Time Complexity: 6
# ------------------
# ...

# %%
x.state()
# Out:
# [('P11', {'MIS': True, 'n': 13}),
#  ('P4', {'MIS': False, 'n': 13}),
#  ('P6', {'MIS': False, 'n': 13}),
#  ('P9', {'MIS': False, 'n': 13}),
#  ('P12', {'MIS': False, 'n': 13}),
#  ('P10', {'MIS': False, 'n': 13}),
#  ('P5', {'MIS': False, 'n': 13}),
#  ('P3', {'MIS': False, 'n': 13}),
#  ('P8', {'MIS': True, 'n': 13}),
#  ('P1', {'MIS': False, 'n': 13}),
#  ('P0', {'MIS': True, 'n': 13}),
#  ('P2', {'MIS': False, 'n': 13}),
#  ('P7', {'MIS': False, 'n': 13})]
