# %%
# %run imports.py

# %% [markdown]
# ### Networks

# %% [markdown]
# #### Ring Network

# %%
x = Bidirectional_Ring(8)
x.draw()

# %%
x.state()
# Out:
# [('P5', {'n': 8}),
#  ('P3', {'n': 8}),
#  ('P7', {'n': 8}),
#  ('P6', {'n': 8}),
#  ('P4', {'n': 8}),
#  ('P0', {'n': 8}),
#  ('P1', {'n': 8}),
#  ('P2', {'n': 8})]

# %% [markdown]
# #### Line Network

# %%
Bidirectional_Line(6).draw()

# %% [markdown]
# #### Random Line Network

# %%
Random_Line_Network(16).draw()

# %%
Random_Line_Network(16, sparsity=0).draw()

# %%
Random_Line_Network(16, sparsity=0.5).draw()

# %%
Random_Line_Network(16, sparsity=float('inf')).draw()

# %% [markdown]
# ### Algorithms

# %% [markdown]
# #### A Basic Algorithm: LCR

# %%
x = Unidirectional_Ring(5)

# %% [markdown]
# ##### Initial Network State

# %%
x.state()
# Out:
# [('P1', {'n': 5}),
#  ('P0', {'n': 5}),
#  ('P4', {'n': 5}),
#  ('P3', {'n': 5}),
#  ('P2', {'n': 5})]

# %%
lcr = LCR(x)
# Out:
# --------------
# Running LCR on
# [P1 -> {P0}, P0 -> {P4}, P4 -> {P3}, P3 -> {P2}, P2 -> {P1}]
# Round 1
# P1.status is non-leader
# P0.status is non-leader
# P3.status is non-leader
# P2.status is non-leader
# Round 2
# P1.status is non-leader
# P0.status is non-leader
# P2.status is non-leader
# Round 3
# P1.status is non-leader
# P0.status is non-leader
# Round 4
# P0.status is non-leader
# Round 5
# P4.status is leader
# LCR Terminated
# Message Complexity: 15
# Time Complexity: 5
# ------------------

# %% [markdown]
# ##### Time Complexity

# %%
print lcr.r, "rounds"
# Out:
# 5 rounds

# %% [markdown]
# ##### Message Complexity

# %%
print lcr.message_count, "messages"
# Out:
# 15 messages

# %% [markdown]
# ##### Final Network State

# %%
x.state()
# Out:
# [('P1', {'n': 5, 'status': 'non-leader'}),
#  ('P0', {'n': 5, 'status': 'non-leader'}),
#  ('P4', {'n': 5, 'status': 'leader'}),
#  ('P3', {'n': 5, 'status': 'non-leader'}),
#  ('P2', {'n': 5, 'status': 'non-leader'})]

# %% [markdown]
# #### Chaining Algorithms

# %%
x = Random_Line_Network(6)

# %%
#Elect a Leader
FloodMax(x, params={'verbosity': Algorithm.QUIET})
# Out:
# FloodMax Terminated
# Message Complexity: 70
# Time Complexity: 6
# ------------------
# <datk.core.algs.FloodMax instance at 0x10ce44368>

# %%
#Construct a BFS tree rooted at the Leader 
SynchBFS(x)
# Out:
# -------------------
# Running SynchBFS on
# [P0 -> {P1, P5}, P1 -> {P0, P5, P3}, P5 -> {P0, P1, P3}, P3 -> {P1, P5, P2}, P2 -> {P3, P4}, P4 -> {P2}]
# Round 1
# P5.parent is None
# P0.parent is P5
# P1.parent is P5
# P3.parent is P5
# Round 2
# P2.parent is P3
# Round 3
# P4.parent is P2
# Round 4
# SynchBFS Terminated
# Message Complexity: 14
# Time Complexity: 4
# ------------------
# <datk.core.algs.SynchBFS instance at 0x10c5e6dd0>

# %%
SynchConvergeHeight(x, params={'draw':True})
# Out:
# --------------------------
# Running _ConvergeHeight on
# [P0 -> {P1, P5}, P1 -> {P0, P5, P3}, P5 -> {P0, P1, P3}, P3 -> {P1, P5, P2}, P2 -> {P3, P4}, P4 -> {P2}]
# Round 1
# Round 2
# Round 3
# Round 4
# P5.height is 3
# _ConvergeHeight Terminated
# Message Complexity: 8
# Time Complexity: 4
# ------------------
# <datk.core.algs._ConvergeHeight instance at 0x10c467710>

# %%
x.state()
# Out:
# [('P0', {'n': 6, 'parent': P5 -> {P0, P1, P3}, 'status': 'non-leader'}),
#  ('P1', {'n': 6, 'parent': P5 -> {P0, P1, P3}, 'status': 'non-leader'}),
#  ('P5', {'height': 3, 'n': 6, 'parent': None, 'status': 'leader'}),
#  ('P3', {'n': 6, 'parent': P5 -> {P0, P1, P3}, 'status': 'non-leader'}),
#  ('P2', {'n': 6, 'parent': P3 -> {P1, P5, P2}, 'status': 'non-leader'}),
#  ('P4', {'n': 6, 'parent': P2 -> {P3, P4}, 'status': 'non-leader'})]

# %% [markdown]
# #### Equivalently, chain them like this:

# %%
x = Random_Line_Network(6)
A = Chain(FloodMax(), Chain(SynchBFS(), SynchConvergeHeight()), params={'verbosity':Algorithm.QUIET})
A(x)
# Out:
# ----------------------------------------------------------
# Running Chain(FloodMax,Chain(SynchBFS,_ConvergeHeight)) on
# [P5 -> {P3, P4}, P3 -> {P5, P4}, P4 -> {P5, P3, P0}, P0 -> {P4, P1}, P1 -> {P0, P2}, P2 -> {P1}]
# -------------------
# Running FloodMax on
# [P5 -> {P3, P4}, P3 -> {P5, P4}, P4 -> {P5, P3, P0}, P0 -> {P4, P1}, P1 -> {P0, P2}, P2 -> {P1}]
# Round 1
# Round 2
# Round 3
# Round 4
# Round 5
# Round 6
# P5.status is leader
# P3.status is non-leader
# P4.status is non-leader
# P0.status is non-leader
# P1.status is non-leader
# P2.status is non-leader
# FloodMax Terminated
# Message Complexity: 60
# Time Complexity: 6
# ------------------
# ------------------------------------------
# Running Chain(SynchBFS,_ConvergeHeight) on
# [P5 -> {P3, P4}, P3 -> {P5, P4}, P4 -> {P5, P3, P0}, P0 -> {P4, P1}, P1 -> {P0, P2}, P2 -> {P1}]
# -------------------
# Running SynchBFS on
# [P5 -> {P3, P4}, P3 -> {P5, P4}, P4 -> {P5, P3, P0}, P0 -> {P4, P1}, P1 -> {P0, P2}, P2 -> {P1}]
# Round 1
# P5.parent is None
# P3.parent is P5
# P4.parent is P5
# Round 2
# P0.parent is P4
# Round 3
# P1.parent is P0
# Round 4
# P2.parent is P1
# Round 5
# SynchBFS Terminated
# Message Complexity: 12
# Time Complexity: 5
# ------------------
# --------------------------
# Running _ConvergeHeight on
# [P5 -> {P3, P4}, P3 -> {P5, P4}, P4 -> {P5, P3, P0}, P0 -> {P4, P1}, P1 -> {P0, P2}, P2 -> {P1}]
# Round 1
# Round 2
# Round 3
# Round 4
# Round 5
# P5.height is 4
# _ConvergeHeight Terminated
# Message Complexity: 11
# Time Complexity: 5
# ------------------

# %%
x.state()
# Out:
# [('P5', {'height': 4, 'n': 6, 'parent': None, 'status': 'leader'}),
#  ('P3', {'n': 6, 'parent': P5 -> {P3, P4}, 'status': 'non-leader'}),
#  ('P4', {'n': 6, 'parent': P5 -> {P3, P4}, 'status': 'non-leader'}),
#  ('P0', {'n': 6, 'parent': P4 -> {P5, P3, P0}, 'status': 'non-leader'}),
#  ('P1', {'n': 6, 'parent': P0 -> {P4, P1}, 'status': 'non-leader'}),
#  ('P2', {'n': 6, 'parent': P1 -> {P0, P2}, 'status': 'non-leader'})]
